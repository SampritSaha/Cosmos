# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv("phl_exoplanet_catalog_2019.csv")

data.head()
# Out:
#        P_NAME  P_STATUS      P_MASS  P_MASS_ERROR_MIN  P_MASS_ERROR_MAX  \
# 0    11 Com b       3.0  6165.86330        -476.74200         476.74200
# 1    11 UMi b       3.0  4684.78480        -794.57001         794.57001
# 2    14 And b       3.0  1525.57440               NaN               NaN
# 3    14 Her b       3.0  1481.07850         -47.67420          47.67420
# 4  16 Cyg B b       3.0   565.73385         -25.42624          25.42624
#
#    P_RADIUS  P_RADIUS_ERROR_MIN  P_RADIUS_ERROR_MAX  P_YEAR   P_UPDATED  ...  \
# 0       NaN                 NaN                 NaN    2007  2014-05-14  ...
# 1       NaN                 NaN                 NaN    2009  2018-09-06  ...
# 2       NaN                 NaN                 NaN    2008  2014-05-14  ...
# 3       NaN                 NaN                 NaN    2002  2018-09-06  ...
# 4       NaN                 NaN                 NaN    1996  2018-09-06  ...
#
# ...

# %%
m=data.S_METALLICITY

# %%
print(m)
# Out:
# 0      -0.35
# 1      -0.02
# 2      -0.24
# 3       0.41
# 4       0.06
#         ...
# 4043    0.00
# 4044    0.00
# 4045   -0.08
# 4046   -0.08
# 4047   -0.08
# Name: S_METALLICITY, Length: 4048, dtype: float64

# %%
df=data[['S_AGE','S_METALLICITY']]

# %%
df.head()
# Out:
#    S_AGE  S_METALLICITY
# 0    NaN          -0.35
# 1    NaN          -0.02
# 2    NaN          -0.24
# 3    NaN           0.41
# 4    NaN           0.06

# %%
df.dropna()
# Out:
#              S_AGE  S_METALLICITY
# 7     6.920000e+00          -0.77
# 8     2.700000e+00          -0.03
# 9     2.700000e+00          -0.03
# 18    4.604000e+00          -0.25
# 19    9.490000e+00          -0.46
# ...            ...            ...
# 4043 -2.147484e+09           0.00
# 4044 -2.147484e+09           0.00
# 4045  7.000000e+00          -0.08
# 4046  7.000000e+00          -0.08
# 4047  7.000000e+00          -0.08
#
# [1957 rows x 2 columns]

# %%
plt.scatter(x=df['S_AGE'], y=df['S_METALLICITY'], s=5);
plt.show();

# %%
plt.xlim(0,16)
plt.ylim(-1,1)
plt.scatter(x=df['S_AGE'], y=df['S_METALLICITY'], s=5);
plt.show();

# %%
plt.xlim(2,6)
plt.ylim(-1,1)
plt.scatter(x=df['S_AGE'], y=df['S_METALLICITY'], s=5);
plt.show();
