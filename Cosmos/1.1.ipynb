# %% [markdown]
# 1.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("phl_exoplanet_catalog_2019.csv")

# %%
data.head()
# Out:
#        P_NAME  P_STATUS      P_MASS  P_MASS_ERROR_MIN  P_MASS_ERROR_MAX  \
# 0    11 Com b       3.0  6165.86330        -476.74200         476.74200
# 1    11 UMi b       3.0  4684.78480        -794.57001         794.57001
# 2    14 And b       3.0  1525.57440               NaN               NaN
# 3    14 Her b       3.0  1481.07850         -47.67420          47.67420
# 4  16 Cyg B b       3.0   565.73385         -25.42624          25.42624
#
#    P_RADIUS  P_RADIUS_ERROR_MIN  P_RADIUS_ERROR_MAX  P_YEAR   P_UPDATED  ...  \
# 0       NaN                 NaN                 NaN    2007  2014-05-14  ...
# 1       NaN                 NaN                 NaN    2009  2018-09-06  ...
# 2       NaN                 NaN                 NaN    2008  2014-05-14  ...
# 3       NaN                 NaN                 NaN    2002  2018-09-06  ...
# 4       NaN                 NaN                 NaN    1996  2018-09-06  ...
#
# ...

# %%
#finding range of data

# %%
max_col=data.max(axis='index')
min_col=data.min(axis='index')

print(max_col)
print(min_col)
# Out:
# P_NAME                   ups And d
# P_STATUS                       3.0
# P_MASS                   17668.059
# P_MASS_ERROR_MIN              0.27
# P_MASS_ERROR_MAX         26630.808
#                            ...
# S_CONSTELLATION_ABR            Vul
# S_CONSTELLATION_ENG           Wolf
# P_RADIUS_EST                77.349
# P_MASS_EST               17668.059
# P_SEMI_MAJOR_AXIS_EST       2500.0
# Length: 108, dtype: object
# P_NAME                   11 Com b
# P_STATUS                      3.0
# P_MASS                    0.01907
# P_MASS_ERROR_MIN        -24965.39
# P_MASS_ERROR_MAX              0.0
#                            ...
# S_CONSTELLATION_ABR           And
# S_CONSTELLATION_ENG      Air Pump
# P_RADIUS_EST                  0.0
# P_MASS_EST                    0.0
# P_SEMI_MAJOR_AXIS_EST      0.0044
# Length: 108, dtype: object
# ...

# %%
#code to make a table of max and mean

# %%
#finding mean of each row

# %%
mean_col = data.mean(axis='index')
print("Mean:\n\n",mean_col)
# Out:
# Mean:
#
#  P_STATUS                   3.000000
# P_MASS                   798.384920
# P_MASS_ERROR_MIN        -152.292232
# P_MASS_ERROR_MAX         190.289692
# P_RADIUS                   4.191426
#                             ...
# P_HABITABLE                0.021986
# P_ESI                      0.261252
# P_RADIUS_EST               5.588647
# P_MASS_EST               323.089993
# P_SEMI_MAJOR_AXIS_EST      4.011385
# Length: 98, dtype: float64
# C:\Users\SAMPRIT SAHA\AppData\Local\Temp\ipykernel_2644\576910895.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_col = data.mean(axis='index')

# %%
#finding median of data

# %%
median_row = data.median(axis='index')
print("Median: \n\n",median_row)
# Out:
# Median:
#
#  P_STATUS                   3.000000
# P_MASS                   273.332080
# P_MASS_ERROR_MIN         -24.154928
# P_MASS_ERROR_MAX          25.108412
# P_RADIUS                   2.331680
#                             ...
# P_HABITABLE                0.000000
# P_ESI                      0.271192
# P_RADIUS_EST               2.667980
# P_MASS_EST                 7.815324
# P_SEMI_MAJOR_AXIS_EST      0.102199
# Length: 98, dtype: float64
# C:\Users\SAMPRIT SAHA\AppData\Local\Temp\ipykernel_2644\1702608738.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   median_row = data.median(axis='index')

# %%
#finding standerd deviation of data

# %%
standerd_deviation = data.std()
print("Standderd Deviation:\n\n",standerd_deviation)
# Out:
# Standderd Deviation:
#
#  P_STATUS                    0.000000
# P_MASS                   1406.808654
# P_MASS_ERROR_MIN          783.366353
# P_MASS_ERROR_MAX         1082.061976
# P_RADIUS                    4.776830
#                             ...
# P_HABITABLE                 0.195731
# P_ESI                       0.131333
# P_RADIUS_EST                5.392733
# P_MASS_EST                965.084290
# P_SEMI_MAJOR_AXIS_EST      62.389968
# Length: 98, dtype: float64
# C:\Users\SAMPRIT SAHA\AppData\Local\Temp\ipykernel_2644\1840419643.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   standerd_deviation = data.std()

# %%
for i in range(0,100):
    plt.title("Mass") # Setting the title 
    plt.scatter(x=data.index, y=data['P_MASS'], s=5); # Plotting the scatter
    plt.show();0
