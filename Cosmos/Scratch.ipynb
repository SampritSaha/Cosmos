# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("phl_exoplanet_catalog_2019.csv")

# %%
data.head()
# Out:
#        P_NAME  P_STATUS      P_MASS  P_MASS_ERROR_MIN  P_MASS_ERROR_MAX  \
# 0    11 Com b       3.0  6165.86330        -476.74200         476.74200
# 1    11 UMi b       3.0  4684.78480        -794.57001         794.57001
# 2    14 And b       3.0  1525.57440               NaN               NaN
# 3    14 Her b       3.0  1481.07850         -47.67420          47.67420
# 4  16 Cyg B b       3.0   565.73385         -25.42624          25.42624
#
#    P_RADIUS  P_RADIUS_ERROR_MIN  P_RADIUS_ERROR_MAX  P_YEAR   P_UPDATED  ...  \
# 0       NaN                 NaN                 NaN    2007  2014-05-14  ...
# 1       NaN                 NaN                 NaN    2009  2018-09-06  ...
# 2       NaN                 NaN                 NaN    2008  2014-05-14  ...
# 3       NaN                 NaN                 NaN    2002  2018-09-06  ...
# 4       NaN                 NaN                 NaN    1996  2018-09-06  ...
#
# ...

# %%
mean_row = data.mean(axis='index')
print(mean_row)
# Out:
# P_STATUS                   3.000000
# P_MASS                   798.384920
# P_MASS_ERROR_MIN        -152.292232
# P_MASS_ERROR_MAX         190.289692
# P_RADIUS                   4.191426
#                             ...
# P_HABITABLE                0.021986
# P_ESI                      0.261252
# P_RADIUS_EST               5.588647
# P_MASS_EST               323.089993
# P_SEMI_MAJOR_AXIS_EST      4.011385
# Length: 98, dtype: float64
# C:\Users\SAMPRIT SAHA\AppData\Local\Temp\ipykernel_23620\1037864364.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_row = data.mean(axis='index')

# %%
mean_col = data.mean(axis='columns')
print(mean_col)
# Out:
# 0       3.438760e+04
# 1       3.112843e+02
# 2       3.853453e+04
# 3       2.036310e+02
# 4       1.709705e+02
#             ...
# 4043   -2.718325e+07
# 4044   -2.788930e+07
# 4045    8.229922e+01
# 4046    7.900826e+01
# 4047    7.766142e+01
# Length: 4048, dtype: float64
# C:\Users\SAMPRIT SAHA\AppData\Local\Temp\ipykernel_23620\2840968964.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean_col = data.mean(axis='columns')

# %%
data.duplicated().sum()
# Out:
# 0

# %%
for i in range(0,100):
    print(data.iloc[i].S_CONSTELLATION_ENG)
# Out:
# Berenice's Hair
# Little Bear
# Andromeda
# Hercules
# Swan
# Dolphin
# Scorpion
# Herdsman
# Sextant
# Sextant
# Whale
# Furnace
# Bull
# Centaur
# Swan
# Winged Horse
# Lizard
# Ram
# Big Bear
# Dragon
# Big Bear
# Big Bear
# Big Bear
# River
# Winged Horse
# Crab
# Crab
# Crab
# Crab
# Crab
# Lynx
# Virgin
# Virgin
# Virgin
# Big Dog
# Virgin
# Whale
# Little Bear
# Whale
# Water Carrier
# Painter's Easel
# Virgin
# Winged Horse
# Lion
# Serpent
# Lion
# Lion
# Fishes
# Bull
# Perseus
# Perseus
# Perseus
# Hunter
# Hunter
# Sextant
# Sextant
# Cup
# Shield
# Stern
# Whale
# Herdsman
# Chameleon
# Bull
# Chameleon
# Unicorn
# Eagle
# Serpent
# Unicorn
# Unicorn
# Unicorn
# Shield
# Shield
# Unicorn
# Unicorn
# Eagle
# Unicorn
# Unicorn
# Unicorn
# Serpent
# Serpent
# Unicorn
# Unicorn
# Serpent Holder
# Serpent Holder
# Serpent
# Serpent
# Serpent Holder
# Eagle
# Unicorn
# Unicorn
# Serpent Holder
# Unicorn
# Unicorn
# Eagle
# Serpent
# Unicorn
# Hunting Dogs
# Sails
# Bull
# ...

# %%
plt.ylim(0,20000) # Setting y limits so the axis are consistent
plt.title("Mass") # Setting the title 
plt.scatter(x=data.index, y=data['P_MASS'], s=5); # Plotting the scatter
plt.show(); # Telling matplotlib to show the chart

#plt.title("High Variance")
#plt.ylim(-40,40)
#plt.scatter(x=df.index, y=df['high_var'], s=5);
#plt.hlines(y=df['high_var'].mean(), xmin=0, xmax=data_points);

# %%
data.head(1)
# Out:
#      P_NAME  P_STATUS     P_MASS  P_MASS_ERROR_MIN  P_MASS_ERROR_MAX  \
# 0  11 Com b       3.0  6165.8633          -476.742           476.742
#
#    P_RADIUS  P_RADIUS_ERROR_MIN  P_RADIUS_ERROR_MAX  P_YEAR   P_UPDATED  ...  \
# 0       NaN                 NaN                 NaN    2007  2014-05-14  ...
#
#    P_HABZONE_CON  P_TYPE_TEMP  P_HABITABLE     P_ESI  S_CONSTELLATION  \
# 0              0          Hot            0  0.083813   Coma Berenices
#
#    S_CONSTELLATION_ABR  S_CONSTELLATION_ENG  P_RADIUS_EST  P_MASS_EST  \
# 0                  Com      Berenice's Hair     12.082709   6165.8633
#
#    P_SEMI_MAJOR_AXIS_EST
# 0                   1.29
#
# [1 rows x 112 columns]

# %%
plt.ylim(1985,2020) # Setting y limits so the axis are consistent
plt.title("M") # Setting the title 
plt.scatter(x=data['P_MASS'], y=data['P_YEAR'], s=5); # Plotting the scatter
plt.show(); # Telling matplotlib to show the chart

# %%
plt.ylim(1985,2020) # Setting y limits so the axis are consistent
plt.title("2.1") # Setting the title 
plt.scatter(x=data['P_TYPE_TEMP'], y=data['P_ESI'], s=5); # Plotting the scatter
plt.show(); # Telling matplotlib to show the chart
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 plt.ylim(1985,2020) # Setting y limits so the axis are consistent
#       2 plt.title("2.1") # Setting the title
# ----> 3 plt.scatter(x=data['P_TYPE_TEMP'], y=data['P_ESI'], s=5); # Plotting the scatter
#       4 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2835, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2830 @_copy_docstring_and_deprecators(Axes.scatter)
#    2831 def scatter(
#    2832         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2833         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2834         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2835     __ret = gca().scatter(
# ...

# %%
data.head()
# Out:
#        P_NAME  P_STATUS      P_MASS  P_MASS_ERROR_MIN  P_MASS_ERROR_MAX  \
# 0    11 Com b       3.0  6165.86330        -476.74200         476.74200
# 1    11 UMi b       3.0  4684.78480        -794.57001         794.57001
# 2    14 And b       3.0  1525.57440               NaN               NaN
# 3    14 Her b       3.0  1481.07850         -47.67420          47.67420
# 4  16 Cyg B b       3.0   565.73385         -25.42624          25.42624
#
#    P_RADIUS  P_RADIUS_ERROR_MIN  P_RADIUS_ERROR_MAX  P_YEAR   P_UPDATED  ...  \
# 0       NaN                 NaN                 NaN    2007  2014-05-14  ...
# 1       NaN                 NaN                 NaN    2009  2018-09-06  ...
# 2       NaN                 NaN                 NaN    2008  2014-05-14  ...
# 3       NaN                 NaN                 NaN    2002  2018-09-06  ...
# 4       NaN                 NaN                 NaN    1996  2018-09-06  ...
#
# ...

# %%
data2=data[['P_YEAR','P_DETECTION','P_HABITABLE']]
data2.head()
# Out:
#    P_YEAR      P_DETECTION  P_HABITABLE
# 0    2007  Radial Velocity            0
# 1    2009  Radial Velocity            0
# 2    2008  Radial Velocity            0
# 3    2002  Radial Velocity            0
# 4    1996  Radial Velocity            0

# %%
 data.pivot_table(index='P_YEAR',columns='P_DETECTION',values='P_HABITABLE')
# Out:
# P_DETECTION  Astrometry  Eclipse Timing Variations  Imaging  Microlensing  \
# P_YEAR
# 1989                NaN                        NaN      NaN           NaN
# 1992                NaN                        NaN      NaN           NaN
# 1994                NaN                        NaN      NaN           NaN
# 1995                NaN                        NaN      NaN           NaN
# 1996                NaN                        NaN      NaN           NaN
# 1997                NaN                        NaN      NaN           NaN
# 1998                NaN                        NaN      NaN           NaN
# 1999                NaN                        NaN      NaN           NaN
# 2000                NaN                        NaN      NaN           NaN
# 2001                NaN                        NaN      NaN           NaN
# 2002                NaN                        NaN      NaN           NaN
# 2003                NaN                        NaN      NaN           NaN
# ...
