# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv("phl_exoplanet_catalog_2019.csv")

data.head()
# Out:
#        P_NAME  P_STATUS      P_MASS  P_MASS_ERROR_MIN  P_MASS_ERROR_MAX  \
# 0    11 Com b       3.0  6165.86330        -476.74200         476.74200
# 1    11 UMi b       3.0  4684.78480        -794.57001         794.57001
# 2    14 And b       3.0  1525.57440               NaN               NaN
# 3    14 Her b       3.0  1481.07850         -47.67420          47.67420
# 4  16 Cyg B b       3.0   565.73385         -25.42624          25.42624
#
#    P_RADIUS  P_RADIUS_ERROR_MIN  P_RADIUS_ERROR_MAX  P_YEAR   P_UPDATED  ...  \
# 0       NaN                 NaN                 NaN    2007  2014-05-14  ...
# 1       NaN                 NaN                 NaN    2009  2018-09-06  ...
# 2       NaN                 NaN                 NaN    2008  2014-05-14  ...
# 3       NaN                 NaN                 NaN    2002  2018-09-06  ...
# 4       NaN                 NaN                 NaN    1996  2018-09-06  ...
#
# ...

# %%
df = data.sort_values("P_YEAR")

# %%
df.head()
# Out:
#               P_NAME  P_STATUS       P_MASS  P_MASS_ERROR_MIN  \
# 386      HD 114762 b       3.0  3397.581400       -177.983680
# 3771  PSR B1257+12 c       3.0     4.300213         -0.200232
# 3772  PSR B1257+12 d       3.0     3.899750         -0.200232
# 3770  PSR B1257+12 b       3.0     0.019070         -0.003178
# 24          51 Peg b       3.0   150.014820        -12.395292
#
#       P_MASS_ERROR_MAX  P_RADIUS  P_RADIUS_ERROR_MIN  P_RADIUS_ERROR_MAX  \
# 386         177.983680       NaN                 NaN                 NaN
# 3771          0.200232       NaN                 NaN                 NaN
# 3772          0.200232       NaN                 NaN                 NaN
# 3770          0.003178       NaN                 NaN                 NaN
# 24           12.395292       NaN                 NaN                 NaN
#
#       P_YEAR   P_UPDATED  ...  P_HABZONE_CON  P_TYPE_TEMP  P_HABITABLE  \
# 386     1989  2018-09-06  ...              0          Hot            0
# ...

# %%
df2 = data.sort_values("P_YEAR",ascending=False)
df2.head()
# Out:
#                P_NAME  P_STATUS       P_MASS  P_MASS_ERROR_MIN  \
# 4047        GJ 1061 d       3.0     1.680000          0.240000
# 857        HD 92987 b       3.0  5364.936700       -206.588200
# 3709  NSVS 14256825 b       3.0  4497.266200        -50.852480
# 3706         NGTS-5 b       3.0    72.782613        -11.759636
# 3705         NGTS-4 b       3.0    20.598433         -3.000296
#
#       P_MASS_ERROR_MAX  P_RADIUS  P_RADIUS_ERROR_MIN  P_RADIUS_ERROR_MAX  \
# 4047          0.250000       NaN                 NaN                 NaN
# 857         219.301320       NaN                 NaN                 NaN
# 3709         50.852480       NaN                 NaN                 NaN
# 3706         11.759636  12.73456            -0.25783             0.25783
# 3705          3.000296   3.18364            -0.25783             0.25783
#
#       P_YEAR   P_UPDATED  ...  P_HABZONE_CON  P_TYPE_TEMP  P_HABITABLE  \
# 4047    2019      9/3/19  ...              1         Warm            1
# ...

# %%
plt.title("Year vs mass") # Setting the title 
plt.scatter(y=data['P_MASS'], x=data['P_HABITABLE'], s=10); # Plotting the scatter
plt.show();
